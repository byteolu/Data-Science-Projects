# %% [markdown]
# <a href="https://colab.research.google.com/github/byteolu/Data-Science-Projects/blob/main/Google_Trends_API_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   Google Trends Analysis [ Python ]

# %% [markdown]
# I will be using Google Trends API to analyze the daily searches on Google. To start I need to install or check if my system has the Pytrends Library.

# %%
pip install pytrends
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16126 sha256=41477167f3e949d02a2792f86ed279fac89d9e031af88d6fa58b7b7581bc6d35
#   Stored in directory: /root/.cache/pip/wheels/07/6f/5c/8174f98dec1bfbc7d5da4092854afcbcff4b26c3d9b66b5183
# Successfully built pytrends
# ...

# %% [markdown]
# With the Pytrends library installed in our system, we can start importing the python libraries to run this analysis.

# %%
import pandas as pd

# %%
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %% [markdown]
# I will create a DataFrame of the top 10 countries which search for "Data Science" on Google, and then analyze the trends.

# %%
trends.build_payload(kw_list=["Data Science"])
data = trends.interest_by_region()
data = data.sort_values(by="Data Science", ascending=False)
data = data.head(10)
print(data)
# Out:
#            Data Science
# geoName
# China               100
# Singapore            97
# India                97
# Ethiopia             92
# Nigeria              78
# Pakistan             66
# Ghana                65
# Nepal                65
# Kenya                63
# Hong Kong            51

# %% [markdown]
# Perfect! With the results shown above, the search quesries on "Data Science" are mostly done in China.

# %% [markdown]
# # Bar Chart To Visualize The Data

# %%
data.reset_index().plot(x="Geographic Name", y="Data Science", 
                        figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %% [markdown]
# # Total Search Queries Based on "Data Science"

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Data Science'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['Data Science'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches For Data Science', fontweight='bold' )
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %% [markdown]
# # Conclusion
# Lets go!! If you look at the graph you can see the searches based on 'Data Science'! The Google search queries for 'DS' started to increase at the start of 2018 and the peak of the searches were at the start of 2022. Using Google API we can analyze searches based on any keyword.
# We created a tool to pinpoint 10 Countries with the highest number of searches for "Data Science" and also determined how the number of "Data Science" searches queries changed over time. After we completed the analysis, we used Matplot.lib to vizualization our findings.
